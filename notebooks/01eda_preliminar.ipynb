# %%
# tratamiento de dados
import pandas as pd
pd.set_option('display.max_columns', None)
#-------------------------------

# exploracion de archivos
import sys
sys.path.append('../')
#-------------------------------

#funciones personalizadas
from src import sd_eda as se
#-------------------------------

# %%
df = pd.read_csv("../data/data_raw.csv")

# %%
se.eda_preliminar(df)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 342       343     A  2022-03-26           0             HOME      P1081
# 1704     1705     A  2022-01-05           0             TOYS      P1585
# 1498     1499     A  2022-02-08           0             TOYS      P1381
# 216       217     A  2022-03-26           0      ELECTRONICS      P1894
# 692       693     B  2022-01-23           0         FASHHION      P1520
#
#      Product Name  Quantity   Price Discount Total Value Payment Method  \
# 342          Sofa         0  134,77     0,29         0,0            NaN
# 1704   Board Game         0    94,5     0,18         0,0            NaN
# 1498         Doll         0   30,75      0,3         0,0            NaN
# 216    Headphones         0   749,9      0,1         0,0            NaN
# 692         Dress         0    83,9     0,13         0,0            NaN
#
#      Shipping Method Region  Customer Age Customer Gender   Device  \
# ...
