# %%
# tratamiento de dados
import pandas as pd
pd.set_option('display.max_columns', None)
#-------------------------------

# exploracion de archivos
import sys
sys.path.append('../')
#-------------------------------

#funciones personalizadas
from src import sp_eda as se
#-------------------------------

# %%
df = pd.read_csv("../data/data_raw.csv")

# %%
se.eda_preliminar(df)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 1345     1346     A  2022-02-26           0         FASHHION      P1791
# 1039     1040     A  2022-01-29           1           SPORTS      P1010
# 189       190     A  2022-01-20           1            BOOKS      P1616
# 1404     1405     B  2022-03-09           1           SPORTS      P1937
# 1181     1182     A  2022-02-14           0      ELECTRONICS      P1584
#
#        Product Name  Quantity   Price Discount Total Value    Payment Method  \
# 1345       Sneakers         0  117,49     0,25         0,0               NaN
# 1039  Running Shoes         4  239,57     0,09      872,03     Bank Transfer
# 189         Mystery         2     NaN     0,08       42,21            PayPal
# 1404       Football         4   212,1     0,11      755,08  Cash on Delivery
# 1181     Smartphone         0  869,62     0,08         0,0               NaN
#
# ...
